# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.396522
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.
#
# **Your answer:** Loss is equal to: L = log( exp(f_y[i]) / sum(exp(f_k)) )
#
# For 10 classes, with uniform random distribution, sum(exp(f_k)) is roughly equal to 10\*exp(f_y[i]), so L ~= -log(1/10).

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.352992 analytic: 0.352992, relative error: 3.877922e-09
# numerical: -1.468738 analytic: -1.468738, relative error: 2.109565e-08
# numerical: 0.530355 analytic: 0.530355, relative error: 1.021080e-07
# numerical: -1.713337 analytic: -1.713337, relative error: 1.153431e-09
# numerical: 1.075027 analytic: 1.075027, relative error: 1.959196e-08
# numerical: 2.989777 analytic: 2.989777, relative error: 1.933191e-09
# numerical: -0.448274 analytic: -0.448274, relative error: 1.959891e-08
# numerical: -1.382679 analytic: -1.382679, relative error: 8.268989e-09
# numerical: 2.369573 analytic: 2.369573, relative error: 6.105440e-09
# numerical: -2.096413 analytic: -2.096413, relative error: 1.120839e-08
# numerical: 0.454650 analytic: 0.454650, relative error: 6.266377e-08
# numerical: 0.045545 analytic: 0.045545, relative error: 3.579314e-07
# numerical: 0.047237 analytic: 0.047237, relative error: 1.582379e-07
# numerical: 1.801574 analytic: 1.801574, relative error: 1.154343e-09
# numerical: -1.455104 analytic: -1.455104, relative error: 1.120047e-08
# numerical: 2.968167 analytic: 2.968167, relative error: 1.701395e-08
# numerical: 3.073838 analytic: 3.073838, relative error: 3.983619e-09
# numerical: 0.562153 analytic: 0.562153, relative error: 9.701590e-08
# numerical: -2.637561 analytic: -2.637561, relative error: 1.637935e-08
# numerical: 0.786067 analytic: 0.786067, relative error: 1.001991e-07

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.396522e+00 computed in 0.182408s
# vectorized loss: 2.396522e+00 computed in 0.011514s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [2e-7, 5e-6]
regularization_strengths = [5e2, 1e5]
num_iters = 600

rate = learning_rates[0]
while rate <= learning_rates[1]:
    reg = regularization_strengths[0]
    while reg <= regularization_strengths[1]:
        print "training softmax with rate={} reg={}".format(rate, reg)
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=rate, reg=reg,
                              num_iters=num_iters, verbose=False)
        y_train_pred = softmax.predict(X_train)
        y_val_pred = softmax.predict(X_val)
        train_acc = np.mean(y_train == y_train_pred)
        val_acc = np.mean(y_val == y_val_pred)
        results[(rate,reg)] = (train_acc, val_acc)
        if val_acc > best_val:
            best_val = val_acc
            best_softmax = softmax
        reg *= 2
    rate *= 2

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# training softmax with rate=2e-07 reg=500.0
# training softmax with rate=2e-07 reg=1000.0
# training softmax with rate=2e-07 reg=2000.0
# training softmax with rate=2e-07 reg=4000.0
# training softmax with rate=2e-07 reg=8000.0
# training softmax with rate=2e-07 reg=16000.0
# training softmax with rate=2e-07 reg=32000.0
# training softmax with rate=2e-07 reg=64000.0
# training softmax with rate=4e-07 reg=500.0
# training softmax with rate=4e-07 reg=1000.0
# training softmax with rate=4e-07 reg=2000.0
# training softmax with rate=4e-07 reg=4000.0
# training softmax with rate=4e-07 reg=8000.0
# training softmax with rate=4e-07 reg=16000.0
# training softmax with rate=4e-07 reg=32000.0
# training softmax with rate=4e-07 reg=64000.0
# training softmax with rate=8e-07 reg=500.0
# training softmax with rate=8e-07 reg=1000.0
# training softmax with rate=8e-07 reg=2000.0
# training softmax with rate=8e-07 reg=4000.0
# training softmax with rate=8e-07 reg=8000.0
# training softmax with rate=8e-07 reg=16000.0
# training softmax with rate=8e-07 reg=32000.0
# training softmax with rate=8e-07 reg=64000.0
# training softmax with rate=1.6e-06 reg=500.0
# training softmax with rate=1.6e-06 reg=1000.0
# training softmax with rate=1.6e-06 reg=2000.0
# training softmax with rate=1.6e-06 reg=4000.0
# training softmax with rate=1.6e-06 reg=8000.0
# training softmax with rate=1.6e-06 reg=16000.0
# training softmax with rate=1.6e-06 reg=32000.0
# training softmax with rate=1.6e-06 reg=64000.0
# training softmax with rate=3.2e-06 reg=500.0
# training softmax with rate=3.2e-06 reg=1000.0
# training softmax with rate=3.2e-06 reg=2000.0
# training softmax with rate=3.2e-06 reg=4000.0
# training softmax with rate=3.2e-06 reg=8000.0
# training softmax with rate=3.2e-06 reg=16000.0
# training softmax with rate=3.2e-06 reg=32000.0
# training softmax with rate=3.2e-06 reg=64000.0
# lr 2.000000e-07 reg 5.000000e+02 train accuracy: 0.248531 val accuracy: 0.260000
# lr 2.000000e-07 reg 1.000000e+03 train accuracy: 0.240388 val accuracy: 0.235000
# lr 2.000000e-07 reg 2.000000e+03 train accuracy: 0.247327 val accuracy: 0.246000
# lr 2.000000e-07 reg 4.000000e+03 train accuracy: 0.262408 val accuracy: 0.278000
# lr 2.000000e-07 reg 8.000000e+03 train accuracy: 0.288224 val accuracy: 0.300000
# lr 2.000000e-07 reg 1.600000e+04 train accuracy: 0.338061 val accuracy: 0.359000
# lr 2.000000e-07 reg 3.200000e+04 train accuracy: 0.332673 val accuracy: 0.347000
# lr 2.000000e-07 reg 6.400000e+04 train accuracy: 0.322143 val accuracy: 0.332000
# lr 4.000000e-07 reg 5.000000e+02 train accuracy: 0.277408 val accuracy: 0.286000
# lr 4.000000e-07 reg 1.000000e+03 train accuracy: 0.286429 val accuracy: 0.297000
# lr 4.000000e-07 reg 2.000000e+03 train accuracy: 0.295571 val accuracy: 0.306000
# lr 4.000000e-07 reg 4.000000e+03 train accuracy: 0.326633 val accuracy: 0.340000
# lr 4.000000e-07 reg 8.000000e+03 train accuracy: 0.360367 val accuracy: 0.364000
# lr 4.000000e-07 reg 1.600000e+04 train accuracy: 0.354000 val accuracy: 0.367000
# lr 4.000000e-07 reg 3.200000e+04 train accuracy: 0.336265 val accuracy: 0.353000
# lr 4.000000e-07 reg 6.400000e+04 train accuracy: 0.318408 val accuracy: 0.338000
# lr 8.000000e-07 reg 5.000000e+02 train accuracy: 0.312796 val accuracy: 0.309000
# lr 8.000000e-07 reg 1.000000e+03 train accuracy: 0.326878 val accuracy: 0.331000
# lr 8.000000e-07 reg 2.000000e+03 train accuracy: 0.355898 val accuracy: 0.362000
# lr 8.000000e-07 reg 4.000000e+03 train accuracy: 0.377469 val accuracy: 0.383000
# lr 8.000000e-07 reg 8.000000e+03 train accuracy: 0.369102 val accuracy: 0.392000
# lr 8.000000e-07 reg 1.600000e+04 train accuracy: 0.351939 val accuracy: 0.369000
# lr 8.000000e-07 reg 3.200000e+04 train accuracy: 0.336367 val accuracy: 0.341000
# lr 8.000000e-07 reg 6.400000e+04 train accuracy: 0.325388 val accuracy: 0.335000
# lr 1.600000e-06 reg 5.000000e+02 train accuracy: 0.359694 val accuracy: 0.355000
# lr 1.600000e-06 reg 1.000000e+03 train accuracy: 0.370449 val accuracy: 0.378000
# lr 1.600000e-06 reg 2.000000e+03 train accuracy: 0.381245 val accuracy: 0.392000
# lr 1.600000e-06 reg 4.000000e+03 train accuracy: 0.378224 val accuracy: 0.399000
# lr 1.600000e-06 reg 8.000000e+03 train accuracy: 0.364918 val accuracy: 0.366000
# lr 1.600000e-06 reg 1.600000e+04 train accuracy: 0.350265 val accuracy: 0.362000
# lr 1.600000e-06 reg 3.200000e+04 train accuracy: 0.333122 val accuracy: 0.337000
# lr 1.600000e-06 reg 6.400000e+04 train accuracy: 0.313000 val accuracy: 0.322000
# lr 3.200000e-06 reg 5.000000e+02 train accuracy: 0.355857 val accuracy: 0.337000
# lr 3.200000e-06 reg 1.000000e+03 train accuracy: 0.386735 val accuracy: 0.384000
# lr 3.200000e-06 reg 2.000000e+03 train accuracy: 0.374939 val accuracy: 0.372000
# lr 3.200000e-06 reg 4.000000e+03 train accuracy: 0.368857 val accuracy: 0.356000
# lr 3.200000e-06 reg 8.000000e+03 train accuracy: 0.349551 val accuracy: 0.341000
# lr 3.200000e-06 reg 1.600000e+04 train accuracy: 0.322714 val accuracy: 0.334000
# lr 3.200000e-06 reg 3.200000e+04 train accuracy: 0.261816 val accuracy: 0.271000
# lr 3.200000e-06 reg 6.400000e+04 train accuracy: 0.294796 val accuracy: 0.303000
# best validation accuracy achieved during cross-validation: 0.399000

# %%
softmax = Softmax()
loss_hist = softmax.train(X_train, y_train, learning_rate=1.6e-6, reg=4e3,
                      num_iters=600, verbose=True)
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()
# Out:
# iteration 0 / 600: loss 66.402469
# iteration 100 / 600: loss 18.697732
# iteration 200 / 600: loss 6.391391
# iteration 300 / 600: loss 3.074137
# iteration 400 / 600: loss 2.190432
# iteration 500 / 600: loss 1.986522

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.368000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
