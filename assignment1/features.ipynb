# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 8e-6]
regularization_strengths = [1e3, 1e8]
num_iters = 1000

results = {}
best_val = -1
best_svm = None

rate = learning_rates[0]
while rate <= learning_rates[1]:
    reg = regularization_strengths[0]
    while reg <= regularization_strengths[1]:
        print "training svm with rate={} reg={}".format(rate, reg)
        svm = LinearSVM()
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=rate, reg=reg,
                              num_iters=num_iters, verbose=False)
        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        train_acc = np.mean(y_train == y_train_pred)
        val_acc = np.mean(y_val == y_val_pred)
        results[(rate,reg)] = (train_acc, val_acc)
        if val_acc > best_val:
            best_val = val_acc
            best_svm = svm
        reg *= 2
    rate *= 2

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# training svm with rate=1e-09 reg=1000.0
# training svm with rate=1e-09 reg=2000.0
# training svm with rate=1e-09 reg=4000.0
# training svm with rate=1e-09 reg=8000.0
# training svm with rate=1e-09 reg=16000.0
# training svm with rate=1e-09 reg=32000.0
# training svm with rate=1e-09 reg=64000.0
# training svm with rate=1e-09 reg=128000.0
# training svm with rate=1e-09 reg=256000.0
# training svm with rate=1e-09 reg=512000.0
# training svm with rate=1e-09 reg=1024000.0
# training svm with rate=1e-09 reg=2048000.0
# training svm with rate=1e-09 reg=4096000.0
# training svm with rate=1e-09 reg=8192000.0
# training svm with rate=1e-09 reg=16384000.0
# training svm with rate=1e-09 reg=32768000.0
# training svm with rate=1e-09 reg=65536000.0
# training svm with rate=2e-09 reg=1000.0
# training svm with rate=2e-09 reg=2000.0
# training svm with rate=2e-09 reg=4000.0
# training svm with rate=2e-09 reg=8000.0
# training svm with rate=2e-09 reg=16000.0
# training svm with rate=2e-09 reg=32000.0
# training svm with rate=2e-09 reg=64000.0
# training svm with rate=2e-09 reg=128000.0
# training svm with rate=2e-09 reg=256000.0
# training svm with rate=2e-09 reg=512000.0
# training svm with rate=2e-09 reg=1024000.0
# training svm with rate=2e-09 reg=2048000.0
# training svm with rate=2e-09 reg=4096000.0
# training svm with rate=2e-09 reg=8192000.0
# training svm with rate=2e-09 reg=16384000.0
# training svm with rate=2e-09 reg=32768000.0
# training svm with rate=2e-09 reg=65536000.0
# training svm with rate=4e-09 reg=1000.0
# training svm with rate=4e-09 reg=2000.0
# training svm with rate=4e-09 reg=4000.0
# training svm with rate=4e-09 reg=8000.0
# training svm with rate=4e-09 reg=16000.0
# training svm with rate=4e-09 reg=32000.0
# training svm with rate=4e-09 reg=64000.0
# training svm with rate=4e-09 reg=128000.0
# training svm with rate=4e-09 reg=256000.0
# training svm with rate=4e-09 reg=512000.0
# training svm with rate=4e-09 reg=1024000.0
# training svm with rate=4e-09 reg=2048000.0
# training svm with rate=4e-09 reg=4096000.0
# training svm with rate=4e-09 reg=8192000.0
# training svm with rate=4e-09 reg=16384000.0
# training svm with rate=4e-09 reg=32768000.0
# training svm with rate=4e-09 reg=65536000.0
# training svm with rate=8e-09 reg=1000.0
# training svm with rate=8e-09 reg=2000.0
# training svm with rate=8e-09 reg=4000.0
# training svm with rate=8e-09 reg=8000.0
# training svm with rate=8e-09 reg=16000.0
# training svm with rate=8e-09 reg=32000.0
# training svm with rate=8e-09 reg=64000.0
# training svm with rate=8e-09 reg=128000.0
# training svm with rate=8e-09 reg=256000.0
# training svm with rate=8e-09 reg=512000.0
# training svm with rate=8e-09 reg=1024000.0
# training svm with rate=8e-09 reg=2048000.0
# training svm with rate=8e-09 reg=4096000.0
# training svm with rate=8e-09 reg=8192000.0
# training svm with rate=8e-09 reg=16384000.0
# training svm with rate=8e-09 reg=32768000.0
# training svm with rate=8e-09 reg=65536000.0
# training svm with rate=1.6e-08 reg=1000.0
# training svm with rate=1.6e-08 reg=2000.0
# training svm with rate=1.6e-08 reg=4000.0
# training svm with rate=1.6e-08 reg=8000.0
# training svm with rate=1.6e-08 reg=16000.0
# training svm with rate=1.6e-08 reg=32000.0
# training svm with rate=1.6e-08 reg=64000.0
# training svm with rate=1.6e-08 reg=128000.0
# training svm with rate=1.6e-08 reg=256000.0
# training svm with rate=1.6e-08 reg=512000.0
# training svm with rate=1.6e-08 reg=1024000.0
# training svm with rate=1.6e-08 reg=2048000.0
# training svm with rate=1.6e-08 reg=4096000.0
# training svm with rate=1.6e-08 reg=8192000.0
# training svm with rate=1.6e-08 reg=16384000.0
# training svm with rate=1.6e-08 reg=32768000.0
# training svm with rate=1.6e-08 reg=65536000.0
# training svm with rate=3.2e-08 reg=1000.0
# training svm with rate=3.2e-08 reg=2000.0
# training svm with rate=3.2e-08 reg=4000.0
# training svm with rate=3.2e-08 reg=8000.0
# training svm with rate=3.2e-08 reg=16000.0
# training svm with rate=3.2e-08 reg=32000.0
# training svm with rate=3.2e-08 reg=64000.0
# training svm with rate=3.2e-08 reg=128000.0
# training svm with rate=3.2e-08 reg=256000.0
# training svm with rate=3.2e-08 reg=512000.0
# training svm with rate=3.2e-08 reg=1024000.0
# training svm with rate=3.2e-08 reg=2048000.0
# training svm with rate=3.2e-08 reg=4096000.0
# training svm with rate=3.2e-08 reg=8192000.0
# training svm with rate=3.2e-08 reg=16384000.0
# training svm with rate=3.2e-08 reg=32768000.0
# training svm with rate=3.2e-08 reg=65536000.0
# training svm with rate=6.4e-08 reg=1000.0
# training svm with rate=6.4e-08 reg=2000.0
# training svm with rate=6.4e-08 reg=4000.0
# training svm with rate=6.4e-08 reg=8000.0
# training svm with rate=6.4e-08 reg=16000.0
# training svm with rate=6.4e-08 reg=32000.0
# training svm with rate=6.4e-08 reg=64000.0
# training svm with rate=6.4e-08 reg=128000.0
# training svm with rate=6.4e-08 reg=256000.0
# training svm with rate=6.4e-08 reg=512000.0
# training svm with rate=6.4e-08 reg=1024000.0
# training svm with rate=6.4e-08 reg=2048000.0
# training svm with rate=6.4e-08 reg=4096000.0
# training svm with rate=6.4e-08 reg=8192000.0
# training svm with rate=6.4e-08 reg=16384000.0
# training svm with rate=6.4e-08 reg=32768000.0
# training svm with rate=6.4e-08 reg=65536000.0
# training svm with rate=1.28e-07 reg=1000.0
# training svm with rate=1.28e-07 reg=2000.0
# training svm with rate=1.28e-07 reg=4000.0
# training svm with rate=1.28e-07 reg=8000.0
# training svm with rate=1.28e-07 reg=16000.0
# training svm with rate=1.28e-07 reg=32000.0
# training svm with rate=1.28e-07 reg=64000.0
# training svm with rate=1.28e-07 reg=128000.0
# training svm with rate=1.28e-07 reg=256000.0
# training svm with rate=1.28e-07 reg=512000.0
# training svm with rate=1.28e-07 reg=1024000.0
# training svm with rate=1.28e-07 reg=2048000.0
# training svm with rate=1.28e-07 reg=4096000.0
# training svm with rate=1.28e-07 reg=8192000.0
# training svm with rate=1.28e-07 reg=16384000.0
# training svm with rate=1.28e-07 reg=32768000.0
# training svm with rate=1.28e-07 reg=65536000.0
# training svm with rate=2.56e-07 reg=1000.0
# training svm with rate=2.56e-07 reg=2000.0
# training svm with rate=2.56e-07 reg=4000.0
# training svm with rate=2.56e-07 reg=8000.0
# training svm with rate=2.56e-07 reg=16000.0
# training svm with rate=2.56e-07 reg=32000.0
# training svm with rate=2.56e-07 reg=64000.0
# training svm with rate=2.56e-07 reg=128000.0
# training svm with rate=2.56e-07 reg=256000.0
# training svm with rate=2.56e-07 reg=512000.0
# training svm with rate=2.56e-07 reg=1024000.0
# training svm with rate=2.56e-07 reg=2048000.0
# training svm with rate=2.56e-07 reg=4096000.0
# training svm with rate=2.56e-07 reg=8192000.0
# training svm with rate=2.56e-07 reg=16384000.0
# training svm with rate=2.56e-07 reg=32768000.0
# training svm with rate=2.56e-07 reg=65536000.0
# training svm with rate=5.12e-07 reg=1000.0
# training svm with rate=5.12e-07 reg=2000.0
# training svm with rate=5.12e-07 reg=4000.0
# training svm with rate=5.12e-07 reg=8000.0
# training svm with rate=5.12e-07 reg=16000.0
# training svm with rate=5.12e-07 reg=32000.0
# training svm with rate=5.12e-07 reg=64000.0
# training svm with rate=5.12e-07 reg=128000.0
# training svm with rate=5.12e-07 reg=256000.0
# training svm with rate=5.12e-07 reg=512000.0
# training svm with rate=5.12e-07 reg=1024000.0
# training svm with rate=5.12e-07 reg=2048000.0
# training svm with rate=5.12e-07 reg=4096000.0
# training svm with rate=5.12e-07 reg=8192000.0
# training svm with rate=5.12e-07 reg=16384000.0
# training svm with rate=5.12e-07 reg=32768000.0
# training svm with rate=5.12e-07 reg=65536000.0
# training svm with rate=1.024e-06 reg=1000.0
# training svm with rate=1.024e-06 reg=2000.0
# training svm with rate=1.024e-06 reg=4000.0
# training svm with rate=1.024e-06 reg=8000.0
# training svm with rate=1.024e-06 reg=16000.0
# training svm with rate=1.024e-06 reg=32000.0
# training svm with rate=1.024e-06 reg=64000.0
# training svm with rate=1.024e-06 reg=128000.0
# training svm with rate=1.024e-06 reg=256000.0
# training svm with rate=1.024e-06 reg=512000.0
# training svm with rate=1.024e-06 reg=1024000.0
# training svm with rate=1.024e-06 reg=2048000.0
# training svm with rate=1.024e-06 reg=4096000.0
# training svm with rate=1.024e-06 reg=8192000.0
# training svm with rate=1.024e-06 reg=16384000.0
# training svm with rate=1.024e-06 reg=32768000.0
# training svm with rate=1.024e-06 reg=65536000.0
# training svm with rate=2.048e-06 reg=1000.0
# training svm with rate=2.048e-06 reg=2000.0
# training svm with rate=2.048e-06 reg=4000.0
# training svm with rate=2.048e-06 reg=8000.0
# training svm with rate=2.048e-06 reg=16000.0
# training svm with rate=2.048e-06 reg=32000.0
# training svm with rate=2.048e-06 reg=64000.0
# training svm with rate=2.048e-06 reg=128000.0
# training svm with rate=2.048e-06 reg=256000.0
# training svm with rate=2.048e-06 reg=512000.0
# training svm with rate=2.048e-06 reg=1024000.0
# training svm with rate=2.048e-06 reg=2048000.0
# training svm with rate=2.048e-06 reg=4096000.0
# training svm with rate=2.048e-06 reg=8192000.0
# training svm with rate=2.048e-06 reg=16384000.0
# training svm with rate=2.048e-06 reg=32768000.0
# training svm with rate=2.048e-06 reg=65536000.0
# training svm with rate=4.096e-06 reg=1000.0
# training svm with rate=4.096e-06 reg=2000.0
# training svm with rate=4.096e-06 reg=4000.0
# training svm with rate=4.096e-06 reg=8000.0
# training svm with rate=4.096e-06 reg=16000.0
# training svm with rate=4.096e-06 reg=32000.0
# training svm with rate=4.096e-06 reg=64000.0
# training svm with rate=4.096e-06 reg=128000.0
# training svm with rate=4.096e-06 reg=256000.0
# training svm with rate=4.096e-06 reg=512000.0
# training svm with rate=4.096e-06 reg=1024000.0
# training svm with rate=4.096e-06 reg=2048000.0
# training svm with rate=4.096e-06 reg=4096000.0
# training svm with rate=4.096e-06 reg=8192000.0
# training svm with rate=4.096e-06 reg=16384000.0
# training svm with rate=4.096e-06 reg=32768000.0
# training svm with rate=4.096e-06 reg=65536000.0
# lr 1.000000e-09 reg 1.000000e+03 train accuracy: 0.103939 val accuracy: 0.106000
# lr 1.000000e-09 reg 2.000000e+03 train accuracy: 0.089531 val accuracy: 0.083000
# lr 1.000000e-09 reg 4.000000e+03 train accuracy: 0.102102 val accuracy: 0.100000
# lr 1.000000e-09 reg 8.000000e+03 train accuracy: 0.082245 val accuracy: 0.077000
# lr 1.000000e-09 reg 1.600000e+04 train accuracy: 0.099224 val accuracy: 0.096000
# lr 1.000000e-09 reg 3.200000e+04 train accuracy: 0.093816 val accuracy: 0.085000
# lr 1.000000e-09 reg 6.400000e+04 train accuracy: 0.095143 val accuracy: 0.107000
# lr 1.000000e-09 reg 1.280000e+05 train accuracy: 0.113122 val accuracy: 0.120000
# lr 1.000000e-09 reg 2.560000e+05 train accuracy: 0.102000 val accuracy: 0.098000
# lr 1.000000e-09 reg 5.120000e+05 train accuracy: 0.090755 val accuracy: 0.096000
# lr 1.000000e-09 reg 1.024000e+06 train accuracy: 0.119592 val accuracy: 0.105000
# lr 1.000000e-09 reg 2.048000e+06 train accuracy: 0.105429 val accuracy: 0.117000
# lr 1.000000e-09 reg 4.096000e+06 train accuracy: 0.088061 val accuracy: 0.082000
# lr 1.000000e-09 reg 8.192000e+06 train accuracy: 0.127837 val accuracy: 0.132000
# lr 1.000000e-09 reg 1.638400e+07 train accuracy: 0.416041 val accuracy: 0.421000
# lr 1.000000e-09 reg 3.276800e+07 train accuracy: 0.413735 val accuracy: 0.418000
# lr 1.000000e-09 reg 6.553600e+07 train accuracy: 0.402939 val accuracy: 0.405000
# lr 2.000000e-09 reg 1.000000e+03 train accuracy: 0.098102 val accuracy: 0.083000
# lr 2.000000e-09 reg 2.000000e+03 train accuracy: 0.086735 val accuracy: 0.097000
# lr 2.000000e-09 reg 4.000000e+03 train accuracy: 0.099878 val accuracy: 0.092000
# lr 2.000000e-09 reg 8.000000e+03 train accuracy: 0.082082 val accuracy: 0.092000
# lr 2.000000e-09 reg 1.600000e+04 train accuracy: 0.118571 val accuracy: 0.134000
# lr 2.000000e-09 reg 3.200000e+04 train accuracy: 0.088041 val accuracy: 0.081000
# lr 2.000000e-09 reg 6.400000e+04 train accuracy: 0.112061 val accuracy: 0.123000
# lr 2.000000e-09 reg 1.280000e+05 train accuracy: 0.105122 val accuracy: 0.092000
# lr 2.000000e-09 reg 2.560000e+05 train accuracy: 0.103959 val accuracy: 0.123000
# lr 2.000000e-09 reg 5.120000e+05 train accuracy: 0.130020 val accuracy: 0.141000
# lr 2.000000e-09 reg 1.024000e+06 train accuracy: 0.091918 val accuracy: 0.071000
# lr 2.000000e-09 reg 2.048000e+06 train accuracy: 0.080184 val accuracy: 0.081000
# lr 2.000000e-09 reg 4.096000e+06 train accuracy: 0.186306 val accuracy: 0.198000
# lr 2.000000e-09 reg 8.192000e+06 train accuracy: 0.417265 val accuracy: 0.425000
# lr 2.000000e-09 reg 1.638400e+07 train accuracy: 0.408878 val accuracy: 0.423000
# lr 2.000000e-09 reg 3.276800e+07 train accuracy: 0.414388 val accuracy: 0.422000
# lr 2.000000e-09 reg 6.553600e+07 train accuracy: 0.412898 val accuracy: 0.410000
# lr 4.000000e-09 reg 1.000000e+03 train accuracy: 0.084735 val accuracy: 0.094000
# lr 4.000000e-09 reg 2.000000e+03 train accuracy: 0.114755 val accuracy: 0.095000
# lr 4.000000e-09 reg 4.000000e+03 train accuracy: 0.093612 val accuracy: 0.105000
# lr 4.000000e-09 reg 8.000000e+03 train accuracy: 0.113837 val accuracy: 0.105000
# lr 4.000000e-09 reg 1.600000e+04 train accuracy: 0.095265 val accuracy: 0.099000
# lr 4.000000e-09 reg 3.200000e+04 train accuracy: 0.101490 val accuracy: 0.105000
# lr 4.000000e-09 reg 6.400000e+04 train accuracy: 0.104939 val accuracy: 0.100000
# lr 4.000000e-09 reg 1.280000e+05 train accuracy: 0.098224 val accuracy: 0.084000
# lr 4.000000e-09 reg 2.560000e+05 train accuracy: 0.116653 val accuracy: 0.111000
# lr 4.000000e-09 reg 5.120000e+05 train accuracy: 0.088020 val accuracy: 0.096000
# lr 4.000000e-09 reg 1.024000e+06 train accuracy: 0.101918 val accuracy: 0.104000
# lr 4.000000e-09 reg 2.048000e+06 train accuracy: 0.289898 val accuracy: 0.328000
# lr 4.000000e-09 reg 4.096000e+06 train accuracy: 0.416510 val accuracy: 0.421000
# lr 4.000000e-09 reg 8.192000e+06 train accuracy: 0.409755 val accuracy: 0.398000
# lr 4.000000e-09 reg 1.638400e+07 train accuracy: 0.402673 val accuracy: 0.395000
# lr 4.000000e-09 reg 3.276800e+07 train accuracy: 0.401939 val accuracy: 0.407000
# lr 4.000000e-09 reg 6.553600e+07 train accuracy: 0.393163 val accuracy: 0.383000
# lr 8.000000e-09 reg 1.000000e+03 train accuracy: 0.108837 val accuracy: 0.104000
# lr 8.000000e-09 reg 2.000000e+03 train accuracy: 0.127592 val accuracy: 0.131000
# lr 8.000000e-09 reg 4.000000e+03 train accuracy: 0.121429 val accuracy: 0.099000
# lr 8.000000e-09 reg 8.000000e+03 train accuracy: 0.091714 val accuracy: 0.088000
# lr 8.000000e-09 reg 1.600000e+04 train accuracy: 0.114265 val accuracy: 0.115000
# lr 8.000000e-09 reg 3.200000e+04 train accuracy: 0.101857 val accuracy: 0.112000
# lr 8.000000e-09 reg 6.400000e+04 train accuracy: 0.093122 val accuracy: 0.087000
# lr 8.000000e-09 reg 1.280000e+05 train accuracy: 0.079469 val accuracy: 0.083000
# lr 8.000000e-09 reg 2.560000e+05 train accuracy: 0.087612 val accuracy: 0.087000
# lr 8.000000e-09 reg 5.120000e+05 train accuracy: 0.107857 val accuracy: 0.116000
# lr 8.000000e-09 reg 1.024000e+06 train accuracy: 0.340102 val accuracy: 0.328000
# lr 8.000000e-09 reg 2.048000e+06 train accuracy: 0.414224 val accuracy: 0.426000
# lr 8.000000e-09 reg 4.096000e+06 train accuracy: 0.412347 val accuracy: 0.418000
# lr 8.000000e-09 reg 8.192000e+06 train accuracy: 0.406429 val accuracy: 0.397000
# lr 8.000000e-09 reg 1.638400e+07 train accuracy: 0.404245 val accuracy: 0.387000
# lr 8.000000e-09 reg 3.276800e+07 train accuracy: 0.374143 val accuracy: 0.370000
# lr 8.000000e-09 reg 6.553600e+07 train accuracy: 0.347551 val accuracy: 0.326000
# lr 1.600000e-08 reg 1.000000e+03 train accuracy: 0.103878 val accuracy: 0.082000
# lr 1.600000e-08 reg 2.000000e+03 train accuracy: 0.107673 val accuracy: 0.108000
# lr 1.600000e-08 reg 4.000000e+03 train accuracy: 0.093204 val accuracy: 0.106000
# lr 1.600000e-08 reg 8.000000e+03 train accuracy: 0.085980 val accuracy: 0.070000
# lr 1.600000e-08 reg 1.600000e+04 train accuracy: 0.107959 val accuracy: 0.112000
# lr 1.600000e-08 reg 3.200000e+04 train accuracy: 0.094551 val accuracy: 0.104000
# lr 1.600000e-08 reg 6.400000e+04 train accuracy: 0.114367 val accuracy: 0.116000
# lr 1.600000e-08 reg 1.280000e+05 train accuracy: 0.128857 val accuracy: 0.142000
# lr 1.600000e-08 reg 2.560000e+05 train accuracy: 0.129061 val accuracy: 0.125000
# lr 1.600000e-08 reg 5.120000e+05 train accuracy: 0.385347 val accuracy: 0.370000
# lr 1.600000e-08 reg 1.024000e+06 train accuracy: 0.413959 val accuracy: 0.416000
# lr 1.600000e-08 reg 2.048000e+06 train accuracy: 0.416286 val accuracy: 0.412000
# lr 1.600000e-08 reg 4.096000e+06 train accuracy: 0.409898 val accuracy: 0.412000
# lr 1.600000e-08 reg 8.192000e+06 train accuracy: 0.405429 val accuracy: 0.406000
# lr 1.600000e-08 reg 1.638400e+07 train accuracy: 0.399633 val accuracy: 0.386000
# lr 1.600000e-08 reg 3.276800e+07 train accuracy: 0.364531 val accuracy: 0.356000
# lr 1.600000e-08 reg 6.553600e+07 train accuracy: 0.314469 val accuracy: 0.321000
# lr 3.200000e-08 reg 1.000000e+03 train accuracy: 0.086306 val accuracy: 0.091000
# lr 3.200000e-08 reg 2.000000e+03 train accuracy: 0.107551 val accuracy: 0.125000
# lr 3.200000e-08 reg 4.000000e+03 train accuracy: 0.115857 val accuracy: 0.111000
# lr 3.200000e-08 reg 8.000000e+03 train accuracy: 0.117633 val accuracy: 0.133000
# lr 3.200000e-08 reg 1.600000e+04 train accuracy: 0.100980 val accuracy: 0.111000
# lr 3.200000e-08 reg 3.200000e+04 train accuracy: 0.104796 val accuracy: 0.138000
# lr 3.200000e-08 reg 6.400000e+04 train accuracy: 0.111469 val accuracy: 0.123000
# lr 3.200000e-08 reg 1.280000e+05 train accuracy: 0.153245 val accuracy: 0.161000
# lr 3.200000e-08 reg 2.560000e+05 train accuracy: 0.411980 val accuracy: 0.410000
# lr 3.200000e-08 reg 5.120000e+05 train accuracy: 0.411857 val accuracy: 0.416000
# lr 3.200000e-08 reg 1.024000e+06 train accuracy: 0.414571 val accuracy: 0.413000
# lr 3.200000e-08 reg 2.048000e+06 train accuracy: 0.405041 val accuracy: 0.390000
# lr 3.200000e-08 reg 4.096000e+06 train accuracy: 0.399184 val accuracy: 0.386000
# lr 3.200000e-08 reg 8.192000e+06 train accuracy: 0.390408 val accuracy: 0.386000
# lr 3.200000e-08 reg 1.638400e+07 train accuracy: 0.377735 val accuracy: 0.391000
# lr 3.200000e-08 reg 3.276800e+07 train accuracy: 0.342694 val accuracy: 0.322000
# lr 3.200000e-08 reg 6.553600e+07 train accuracy: 0.102102 val accuracy: 0.100000
# lr 6.400000e-08 reg 1.000000e+03 train accuracy: 0.084429 val accuracy: 0.079000
# lr 6.400000e-08 reg 2.000000e+03 train accuracy: 0.107102 val accuracy: 0.098000
# lr 6.400000e-08 reg 4.000000e+03 train accuracy: 0.112000 val accuracy: 0.120000
# lr 6.400000e-08 reg 8.000000e+03 train accuracy: 0.113082 val accuracy: 0.088000
# lr 6.400000e-08 reg 1.600000e+04 train accuracy: 0.124633 val accuracy: 0.157000
# lr 6.400000e-08 reg 3.200000e+04 train accuracy: 0.104184 val accuracy: 0.102000
# lr 6.400000e-08 reg 6.400000e+04 train accuracy: 0.220061 val accuracy: 0.241000
# lr 6.400000e-08 reg 1.280000e+05 train accuracy: 0.412694 val accuracy: 0.428000
# lr 6.400000e-08 reg 2.560000e+05 train accuracy: 0.415735 val accuracy: 0.410000
# lr 6.400000e-08 reg 5.120000e+05 train accuracy: 0.411898 val accuracy: 0.423000
# lr 6.400000e-08 reg 1.024000e+06 train accuracy: 0.416816 val accuracy: 0.411000
# lr 6.400000e-08 reg 2.048000e+06 train accuracy: 0.403694 val accuracy: 0.411000
# lr 6.400000e-08 reg 4.096000e+06 train accuracy: 0.391408 val accuracy: 0.382000
# lr 6.400000e-08 reg 8.192000e+06 train accuracy: 0.389612 val accuracy: 0.382000
# lr 6.400000e-08 reg 1.638400e+07 train accuracy: 0.318735 val accuracy: 0.305000
# lr 6.400000e-08 reg 3.276800e+07 train accuracy: 0.108796 val accuracy: 0.120000
# lr 6.400000e-08 reg 6.553600e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.280000e-07 reg 1.000000e+03 train accuracy: 0.104490 val accuracy: 0.101000
# lr 1.280000e-07 reg 2.000000e+03 train accuracy: 0.105367 val accuracy: 0.117000
# lr 1.280000e-07 reg 4.000000e+03 train accuracy: 0.112122 val accuracy: 0.095000
# lr 1.280000e-07 reg 8.000000e+03 train accuracy: 0.142959 val accuracy: 0.133000
# lr 1.280000e-07 reg 1.600000e+04 train accuracy: 0.161327 val accuracy: 0.147000
# lr 1.280000e-07 reg 3.200000e+04 train accuracy: 0.284224 val accuracy: 0.298000
# lr 1.280000e-07 reg 6.400000e+04 train accuracy: 0.413408 val accuracy: 0.413000
# lr 1.280000e-07 reg 1.280000e+05 train accuracy: 0.417714 val accuracy: 0.422000
# lr 1.280000e-07 reg 2.560000e+05 train accuracy: 0.407898 val accuracy: 0.409000
# lr 1.280000e-07 reg 5.120000e+05 train accuracy: 0.410694 val accuracy: 0.420000
# lr 1.280000e-07 reg 1.024000e+06 train accuracy: 0.405102 val accuracy: 0.390000
# lr 1.280000e-07 reg 2.048000e+06 train accuracy: 0.391510 val accuracy: 0.386000
# lr 1.280000e-07 reg 4.096000e+06 train accuracy: 0.364531 val accuracy: 0.371000
# lr 1.280000e-07 reg 8.192000e+06 train accuracy: 0.337959 val accuracy: 0.326000
# lr 1.280000e-07 reg 1.638400e+07 train accuracy: 0.099429 val accuracy: 0.094000
# lr 1.280000e-07 reg 3.276800e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.280000e-07 reg 6.553600e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.560000e-07 reg 1.000000e+03 train accuracy: 0.146959 val accuracy: 0.152000
# lr 2.560000e-07 reg 2.000000e+03 train accuracy: 0.161367 val accuracy: 0.140000
# lr 2.560000e-07 reg 4.000000e+03 train accuracy: 0.137204 val accuracy: 0.149000
# lr 2.560000e-07 reg 8.000000e+03 train accuracy: 0.196429 val accuracy: 0.196000
# lr 2.560000e-07 reg 1.600000e+04 train accuracy: 0.350347 val accuracy: 0.347000
# lr 2.560000e-07 reg 3.200000e+04 train accuracy: 0.415633 val accuracy: 0.409000
# lr 2.560000e-07 reg 6.400000e+04 train accuracy: 0.412184 val accuracy: 0.413000
# lr 2.560000e-07 reg 1.280000e+05 train accuracy: 0.415408 val accuracy: 0.423000
# lr 2.560000e-07 reg 2.560000e+05 train accuracy: 0.409878 val accuracy: 0.410000
# lr 2.560000e-07 reg 5.120000e+05 train accuracy: 0.408980 val accuracy: 0.419000
# lr 2.560000e-07 reg 1.024000e+06 train accuracy: 0.394449 val accuracy: 0.383000
# lr 2.560000e-07 reg 2.048000e+06 train accuracy: 0.368102 val accuracy: 0.364000
# lr 2.560000e-07 reg 4.096000e+06 train accuracy: 0.313327 val accuracy: 0.338000
# lr 2.560000e-07 reg 8.192000e+06 train accuracy: 0.122163 val accuracy: 0.117000
# lr 2.560000e-07 reg 1.638400e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.560000e-07 reg 3.276800e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.560000e-07 reg 6.553600e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.120000e-07 reg 1.000000e+03 train accuracy: 0.170204 val accuracy: 0.174000
# lr 5.120000e-07 reg 2.000000e+03 train accuracy: 0.207020 val accuracy: 0.203000
# lr 5.120000e-07 reg 4.000000e+03 train accuracy: 0.269408 val accuracy: 0.246000
# lr 5.120000e-07 reg 8.000000e+03 train accuracy: 0.397571 val accuracy: 0.401000
# lr 5.120000e-07 reg 1.600000e+04 train accuracy: 0.415408 val accuracy: 0.414000
# lr 5.120000e-07 reg 3.200000e+04 train accuracy: 0.414388 val accuracy: 0.414000
# lr 5.120000e-07 reg 6.400000e+04 train accuracy: 0.410245 val accuracy: 0.436000
# lr 5.120000e-07 reg 1.280000e+05 train accuracy: 0.409327 val accuracy: 0.408000
# lr 5.120000e-07 reg 2.560000e+05 train accuracy: 0.402265 val accuracy: 0.399000
# lr 5.120000e-07 reg 5.120000e+05 train accuracy: 0.396286 val accuracy: 0.402000
# lr 5.120000e-07 reg 1.024000e+06 train accuracy: 0.359653 val accuracy: 0.373000
# lr 5.120000e-07 reg 2.048000e+06 train accuracy: 0.327082 val accuracy: 0.352000
# lr 5.120000e-07 reg 4.096000e+06 train accuracy: 0.101327 val accuracy: 0.104000
# lr 5.120000e-07 reg 8.192000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.120000e-07 reg 1.638400e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.120000e-07 reg 3.276800e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.120000e-07 reg 6.553600e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.024000e-06 reg 1.000000e+03 train accuracy: 0.279592 val accuracy: 0.281000
# lr 1.024000e-06 reg 2.000000e+03 train accuracy: 0.326898 val accuracy: 0.314000
# lr 1.024000e-06 reg 4.000000e+03 train accuracy: 0.408653 val accuracy: 0.400000
# lr 1.024000e-06 reg 8.000000e+03 train accuracy: 0.415694 val accuracy: 0.410000
# lr 1.024000e-06 reg 1.600000e+04 train accuracy: 0.411796 val accuracy: 0.400000
# lr 1.024000e-06 reg 3.200000e+04 train accuracy: 0.403878 val accuracy: 0.400000
# lr 1.024000e-06 reg 6.400000e+04 train accuracy: 0.407041 val accuracy: 0.393000
# lr 1.024000e-06 reg 1.280000e+05 train accuracy: 0.414122 val accuracy: 0.420000
# lr 1.024000e-06 reg 2.560000e+05 train accuracy: 0.380245 val accuracy: 0.391000
# lr 1.024000e-06 reg 5.120000e+05 train accuracy: 0.356449 val accuracy: 0.370000
# lr 1.024000e-06 reg 1.024000e+06 train accuracy: 0.331796 val accuracy: 0.307000
# lr 1.024000e-06 reg 2.048000e+06 train accuracy: 0.098878 val accuracy: 0.099000
# lr 1.024000e-06 reg 4.096000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.024000e-06 reg 8.192000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.024000e-06 reg 1.638400e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.024000e-06 reg 3.276800e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.024000e-06 reg 6.553600e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.048000e-06 reg 1.000000e+03 train accuracy: 0.392980 val accuracy: 0.399000
# lr 2.048000e-06 reg 2.000000e+03 train accuracy: 0.416245 val accuracy: 0.418000
# lr 2.048000e-06 reg 4.000000e+03 train accuracy: 0.412571 val accuracy: 0.412000
# lr 2.048000e-06 reg 8.000000e+03 train accuracy: 0.412041 val accuracy: 0.410000
# lr 2.048000e-06 reg 1.600000e+04 train accuracy: 0.417265 val accuracy: 0.425000
# lr 2.048000e-06 reg 3.200000e+04 train accuracy: 0.410163 val accuracy: 0.422000
# lr 2.048000e-06 reg 6.400000e+04 train accuracy: 0.392673 val accuracy: 0.410000
# lr 2.048000e-06 reg 1.280000e+05 train accuracy: 0.397408 val accuracy: 0.388000
# lr 2.048000e-06 reg 2.560000e+05 train accuracy: 0.367163 val accuracy: 0.367000
# lr 2.048000e-06 reg 5.120000e+05 train accuracy: 0.303551 val accuracy: 0.290000
# lr 2.048000e-06 reg 1.024000e+06 train accuracy: 0.087327 val accuracy: 0.083000
# lr 2.048000e-06 reg 2.048000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.048000e-06 reg 4.096000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.048000e-06 reg 8.192000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.048000e-06 reg 1.638400e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.048000e-06 reg 3.276800e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.048000e-06 reg 6.553600e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.096000e-06 reg 1.000000e+03 train accuracy: 0.412612 val accuracy: 0.418000
# lr 4.096000e-06 reg 2.000000e+03 train accuracy: 0.415776 val accuracy: 0.419000
# lr 4.096000e-06 reg 4.000000e+03 train accuracy: 0.414143 val accuracy: 0.411000
# lr 4.096000e-06 reg 8.000000e+03 train accuracy: 0.410755 val accuracy: 0.415000
# lr 4.096000e-06 reg 1.600000e+04 train accuracy: 0.415490 val accuracy: 0.413000
# lr 4.096000e-06 reg 3.200000e+04 train accuracy: 0.407184 val accuracy: 0.396000
# lr 4.096000e-06 reg 6.400000e+04 train accuracy: 0.393531 val accuracy: 0.387000
# lr 4.096000e-06 reg 1.280000e+05 train accuracy: 0.368245 val accuracy: 0.385000
# lr 4.096000e-06 reg 2.560000e+05 train accuracy: 0.279306 val accuracy: 0.289000
# lr 4.096000e-06 reg 5.120000e+05 train accuracy: 0.098429 val accuracy: 0.087000
# lr 4.096000e-06 reg 1.024000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.096000e-06 reg 2.048000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.096000e-06 reg 4.096000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.096000e-06 reg 8.192000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.096000e-06 reg 1.638400e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.096000e-06 reg 3.276800e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.096000e-06 reg 6.553600e+07 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.436000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.421

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
# Some of these results are a little strange, like that misclassified image labeled as bird (second from the bottom) - I would say this is a bird, too. Sometimes, I think, classifier gets misguided by background color (or object color, too) - especially for cars and planes. Deers and horses look similar in some way, and all animals have similar colors sometimes. In essence, it just seems that the model doesn't have enough capacity for this task.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

best_val = -1
best_net = None

learning_rates = [1e-2, 5]
regularization_strengths = [1e-4, 1e-1]

rate = learning_rates[0]
while rate <= learning_rates[1]:
    reg = regularization_strengths[0]
    while reg <= regularization_strengths[1]:
        print "training two-layer net with rate={} reg={}".format(rate, reg)
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
        stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
            num_iters=1500, batch_size=200,
            learning_rate=rate, learning_rate_decay=0.95,
            reg=reg, verbose=False)
        val_acc = (net.predict(X_val_feats) == y_val).mean()
        print "validation accuracy: {}".format(val_acc)
        results[(rate,reg)] = val_acc
        if val_acc > best_val:
            best_val = val_acc
            best_net = net
        reg *= 2
    rate *= 2
# Out:
# training two-layer net with rate=0.01 reg=0.0001
# validation accuracy: 0.135
# training two-layer net with rate=0.01 reg=0.0002
# validation accuracy: 0.164
# training two-layer net with rate=0.01 reg=0.0004
# validation accuracy: 0.172
# training two-layer net with rate=0.01 reg=0.0008
# validation accuracy: 0.197
# training two-layer net with rate=0.01 reg=0.0016
# validation accuracy: 0.15
# training two-layer net with rate=0.01 reg=0.0032
# validation accuracy: 0.207
# training two-layer net with rate=0.01 reg=0.0064
# validation accuracy: 0.203
# training two-layer net with rate=0.01 reg=0.0128
# validation accuracy: 0.218
# training two-layer net with rate=0.01 reg=0.0256
# validation accuracy: 0.155
# training two-layer net with rate=0.01 reg=0.0512
# validation accuracy: 0.123
# training two-layer net with rate=0.02 reg=0.0001
# validation accuracy: 0.294
# training two-layer net with rate=0.02 reg=0.0002
# validation accuracy: 0.302
# training two-layer net with rate=0.02 reg=0.0004
# validation accuracy: 0.285
# training two-layer net with rate=0.02 reg=0.0008
# validation accuracy: 0.282
# training two-layer net with rate=0.02 reg=0.0016
# validation accuracy: 0.304
# training two-layer net with rate=0.02 reg=0.0032
# validation accuracy: 0.297
# training two-layer net with rate=0.02 reg=0.0064
# validation accuracy: 0.296
# training two-layer net with rate=0.02 reg=0.0128
# validation accuracy: 0.286
# training two-layer net with rate=0.02 reg=0.0256
# validation accuracy: 0.27
# training two-layer net with rate=0.02 reg=0.0512
# validation accuracy: 0.272
# training two-layer net with rate=0.04 reg=0.0001
# validation accuracy: 0.467
# training two-layer net with rate=0.04 reg=0.0002
# validation accuracy: 0.462
# training two-layer net with rate=0.04 reg=0.0004
# validation accuracy: 0.461
# training two-layer net with rate=0.04 reg=0.0008
# validation accuracy: 0.458
# training two-layer net with rate=0.04 reg=0.0016
# validation accuracy: 0.466
# training two-layer net with rate=0.04 reg=0.0032
# validation accuracy: 0.455
# training two-layer net with rate=0.04 reg=0.0064
# validation accuracy: 0.462
# training two-layer net with rate=0.04 reg=0.0128
# validation accuracy: 0.452
# training two-layer net with rate=0.04 reg=0.0256
# validation accuracy: 0.432
# training two-layer net with rate=0.04 reg=0.0512
# validation accuracy: 0.411
# training two-layer net with rate=0.08 reg=0.0001
# validation accuracy: 0.515
# training two-layer net with rate=0.08 reg=0.0002
# validation accuracy: 0.524
# training two-layer net with rate=0.08 reg=0.0004
# validation accuracy: 0.516
# training two-layer net with rate=0.08 reg=0.0008
# validation accuracy: 0.52
# training two-layer net with rate=0.08 reg=0.0016
# validation accuracy: 0.524
# training two-layer net with rate=0.08 reg=0.0032
# validation accuracy: 0.512
# training two-layer net with rate=0.08 reg=0.0064
# validation accuracy: 0.503
# training two-layer net with rate=0.08 reg=0.0128
# validation accuracy: 0.522
# training two-layer net with rate=0.08 reg=0.0256
# validation accuracy: 0.503
# training two-layer net with rate=0.08 reg=0.0512
# validation accuracy: 0.475
# training two-layer net with rate=0.16 reg=0.0001
# validation accuracy: 0.558
# training two-layer net with rate=0.16 reg=0.0002
# validation accuracy: 0.553
# training two-layer net with rate=0.16 reg=0.0004
# validation accuracy: 0.543
# training two-layer net with rate=0.16 reg=0.0008
# validation accuracy: 0.549
# training two-layer net with rate=0.16 reg=0.0016
# validation accuracy: 0.539
# training two-layer net with rate=0.16 reg=0.0032
# validation accuracy: 0.535
# training two-layer net with rate=0.16 reg=0.0064
# validation accuracy: 0.535
# training two-layer net with rate=0.16 reg=0.0128
# validation accuracy: 0.52
# training two-layer net with rate=0.16 reg=0.0256
# validation accuracy: 0.503
# training two-layer net with rate=0.16 reg=0.0512
# validation accuracy: 0.488
# training two-layer net with rate=0.32 reg=0.0001
# validation accuracy: 0.583
# training two-layer net with rate=0.32 reg=0.0002
# validation accuracy: 0.596
# training two-layer net with rate=0.32 reg=0.0004
# validation accuracy: 0.57
# training two-layer net with rate=0.32 reg=0.0008
# validation accuracy: 0.568
# training two-layer net with rate=0.32 reg=0.0016
# validation accuracy: 0.579
# training two-layer net with rate=0.32 reg=0.0032
# validation accuracy: 0.571
# training two-layer net with rate=0.32 reg=0.0064
# validation accuracy: 0.569
# training two-layer net with rate=0.32 reg=0.0128
# validation accuracy: 0.524
# training two-layer net with rate=0.32 reg=0.0256
# validation accuracy: 0.51
# training two-layer net with rate=0.32 reg=0.0512
# validation accuracy: 0.492
# training two-layer net with rate=0.64 reg=0.0001
# validation accuracy: 0.581
# training two-layer net with rate=0.64 reg=0.0002
# validation accuracy: 0.576
# training two-layer net with rate=0.64 reg=0.0004
# validation accuracy: 0.567
# training two-layer net with rate=0.64 reg=0.0008
# validation accuracy: 0.578
# training two-layer net with rate=0.64 reg=0.0016
# validation accuracy: 0.595
# training two-layer net with rate=0.64 reg=0.0032
# validation accuracy: 0.588
# training two-layer net with rate=0.64 reg=0.0064
# validation accuracy: 0.565
# training two-layer net with rate=0.64 reg=0.0128
# validation accuracy: 0.527
# training two-layer net with rate=0.64 reg=0.0256
# validation accuracy: 0.49
# training two-layer net with rate=0.64 reg=0.0512
# validation accuracy: 0.482
# training two-layer net with rate=1.28 reg=0.0001
# validation accuracy: 0.552
# training two-layer net with rate=1.28 reg=0.0002
# validation accuracy: 0.568
# training two-layer net with rate=1.28 reg=0.0004
# validation accuracy: 0.562
# training two-layer net with rate=1.28 reg=0.0008
# validation accuracy: 0.545
# training two-layer net with rate=1.28 reg=0.0016
# validation accuracy: 0.57
# training two-layer net with rate=1.28 reg=0.0032
# validation accuracy: 0.574
# training two-layer net with rate=1.28 reg=0.0064
# validation accuracy: 0.546
# training two-layer net with rate=1.28 reg=0.0128
# validation accuracy: 0.479
# training two-layer net with rate=1.28 reg=0.0256
# validation accuracy: 0.419
# training two-layer net with rate=1.28 reg=0.0512
# validation accuracy: 0.448
# training two-layer net with rate=2.56 reg=0.0001
# validation accuracy: 0.543
# training two-layer net with rate=2.56 reg=0.0002
# validation accuracy: 0.532
# training two-layer net with rate=2.56 reg=0.0004
# validation accuracy: 0.534
# training two-layer net with rate=2.56 reg=0.0008
# validation accuracy: 0.556
# training two-layer net with rate=2.56 reg=0.0016
# validation accuracy: 0.535
# training two-layer net with rate=2.56 reg=0.0032
# validation accuracy: 0.492
# training two-layer net with rate=2.56 reg=0.0064
# validation accuracy: 0.512
# training two-layer net with rate=2.56 reg=0.0128
# validation accuracy: 0.444
# training two-layer net with rate=2.56 reg=0.0256
# validation accuracy: 0.448
# training two-layer net with rate=2.56 reg=0.0512
# validation accuracy: 0.339

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.564

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
